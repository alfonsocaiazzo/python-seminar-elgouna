# %% [markdown]
# # Analysis of COVId19 Outbreak data
#
# Datasource: [Ourworldindata](https://ourworldindata.org/coronavirus-data-explorer)

# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# where are my data located
filepath = "/Users/caiazzo/HEDERA/CODES/python-seminar-elgouna/"

# read datasets
full_data = pd.read_csv(filepath+"full_data.csv")


full_data.head()
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths  \
# 0  2020-02-24  Afghanistan        1.0         NaN          1.0           NaN
# 1  2020-02-25  Afghanistan        0.0         NaN          1.0           NaN
# 2  2020-02-26  Afghanistan        0.0         NaN          1.0           NaN
# 3  2020-02-27  Afghanistan        0.0         NaN          1.0           NaN
# 4  2020-02-28  Afghanistan        0.0         NaN          1.0           NaN
#
#    weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# 0           NaN            NaN             NaN              NaN
# 1           NaN            NaN             NaN              NaN
# 2           NaN            NaN             NaN              NaN
# 3           NaN            NaN             NaN              NaN
# 4           NaN            NaN             NaN              NaN

# %%
# let's filter a bit

germany_full_data = full_data.loc[full_data["location"]=="Germany"]
germany_full_data.head()
# Out:
#              date location  new_cases  new_deaths  total_cases  total_deaths  \
# 27212  2020-01-27  Germany        1.0         NaN          1.0           NaN
# 27213  2020-01-28  Germany        3.0         NaN          4.0           NaN
# 27214  2020-01-29  Germany        0.0         NaN          4.0           NaN
# 27215  2020-01-30  Germany        0.0         NaN          4.0           NaN
# 27216  2020-01-31  Germany        1.0         NaN          5.0           NaN
#
#        weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# 27212           NaN            NaN             NaN              NaN
# 27213           NaN            NaN             NaN              NaN
# 27214           NaN            NaN             NaN              NaN
# 27215           NaN            NaN             NaN              NaN
# 27216           NaN            NaN             NaN              NaN

# %%
# additional dataset

latest_data = pd.read_excel(filepath+"owid-covid-latest.xlsx")
latest_data.head()
# Out:
#    iso_code continent     location last_updated_date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan        2021-04-06      56779.0       62.0
# 1  OWID_AFR       NaN       Africa        2021-04-06    4289749.0     9576.0
# 2       ALB    Europe      Albania        2021-04-06     126936.0      141.0
# 3       DZA    Africa      Algeria        2021-04-06     117879.0      140.0
# 4       AND    Europe      Andorra        2021-04-06      12328.0       42.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              56.429        2512.0         4.0                5.143  ...
# 1           12169.714      114319.0       236.0              259.571  ...
# 2             316.143        2283.0         9.0                8.000  ...
# 3             116.857        3112.0         4.0                3.286  ...
# 4              54.857         117.0         0.0                0.286  ...
#
# ...

# %%
# let's get the continent of germany

tmp = latest_data.loc[latest_data['location']=="Germany"]
continent = tmp['continent'].values[0]

continent

# How to do this for all countries? -> let's create a function

# We can actually do the same also for other variables, e.g., population

# for handling all this, we create a "Country" class
# Out:
# 'Europe'

# %%
# update font size
plt.rcParams.update({'font.size': 16})

# create a figure handler
fig, ax = plt.subplots(figsize=(12,9))

# plot bars
plt.bar(germany_full_data['date'][1::10],germany_full_data['total_cases'][1::10]/1e6)


# change x-axis
plt.ylabel("Total cases (Mio.)")
plt.xticks(np.arange(len(germany_full_data['date'][1::10])),germany_full_data['date'][1::10].values,rotation = -90)

plt.tight_layout()
plt.show()
